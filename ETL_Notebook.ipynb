# %% [markdown]
# # ETL Pipeline

# %% [markdown]
# ## Securely Mounting ADLS Gen2 Storage by OAuth
# - To Access Raw Data Ingested using ADF

# %%
container = "raw"
storage_account = "etlprojectspotify"
mount_name = "raw"

result=dbutils.notebook.run("/Workspace/Users/suman.kr.ghorai@gmail.com/utils/mount_utils", 60, {
    "container": container,
    "storage_account": storage_account,
    "mount_name": mount_name
})
print(result)

# %% [markdown]
# ## Bronze Layer
# - Store Raw Data

# %%
result_broze=dbutils.notebook.run("/Workspace/Users/suman.kr.ghorai@gmail.com/medallion_layers/bronze_layer", 60,)
print(result_broze)

# %% [markdown]
# ### Silver Layer
# -  Validation,Transfromation,Enriching Data

# %%
try:
    result_silver = dbutils.notebook.run("/Workspace/Users/suman.kr.ghorai@gmail.com/medallion_layers/silver_layer", 300)
    display(result_silver)
except Exception as e:
    print(f"Error occurred: {e}")
